# %%
# %matplotlib inline

import numpy as np
import matplotlib
import matplotlib.pyplot as plt

import scipy
import scipy.ndimage
import skimage
from skimage import io
import skimage.transform

# %%
I_cameraman = io.imread('cameraman.tif')
I_cameraman = I_cameraman.astype('float32')
#
fig, ax = plt.subplots()
ax.imshow(I_cameraman, cmap='gray', interpolation='nearest')
ax.set_title('cameraman', fontsize=16)
# Out:
# Text(0.5, 1.0, 'cameraman')

# %% [markdown]
# ### Gabor Kernels

# %%
def gabor_kernel(frequency, theta=0, bandwidth=1, 
                 sigma_x=None, sigma_y=None,
                 n_stds=3, offset=0, half_size=None):
    if sigma_x is None:
        sigma_x = _sigma_prefactor(bandwidth) / frequency
    if sigma_y is None:
        sigma_y = _sigma_prefactor(bandwidth) / frequency

    x0 = np.ceil(max(np.abs(n_stds * sigma_x * np.cos(theta)),
                     np.abs(n_stds * sigma_y * np.sin(theta)), 1))
    y0 = np.ceil(max(np.abs(n_stds * sigma_y * np.cos(theta)),
                     np.abs(n_stds * sigma_x * np.sin(theta)), 1))

    if half_size != None:
        x0 = half_size[0]
        y0 = half_size[1] 
          
    y, x = np.mgrid[-y0:y0 + 1, -x0:x0 + 1]

    rotx = x * np.cos(theta) + y * np.sin(theta)
    roty = -x * np.sin(theta) + y * np.cos(theta)

    g = np.zeros(y.shape, dtype=np.complex128)
    g[:] = np.exp(-0.5 * (rotx ** 2 / sigma_x ** 2 + roty ** 2 / sigma_y ** 2))
    g /= 2 * np.pi * sigma_x * sigma_y
    g *= np.exp(1j * (2 * np.pi * frequency * rotx + offset))

    return g

# %%
# prepare filter bank kernels
kernel_list = []
for n in range(0, 4):
    theta = n / 4 * np.pi
    kernel = np.real(gabor_kernel(0.15, theta=theta, sigma_x=3, sigma_y=3))
    kernel_list.append(kernel)
fig, ax = plt.subplots(1,4, figsize=(10, 8), constrained_layout=True)
for n in range(0, 4):
    ax[n].imshow(kernel_list[n], cmap = 'gray')
#    
fig, ax = plt.subplots(1,4, figsize=(10, 8), constrained_layout=True)
for n in range(0, 4):
    I_n = scipy.ndimage.convolve(I_cameraman, kernel_list[n], mode='nearest')
    I_n = np.abs(I_n)
    ax[n].imshow(I_n, cmap = 'gray')

# %%
# prepare filter bank kernels
kernel_list = []
for n in range(0, 10):
    theta = n / 10 * np.pi
    kernel = np.real(gabor_kernel(1, theta=theta, sigma_x=3, sigma_y=3))
    kernel_list.append(kernel)
fig, ax = plt.subplots(1,10, figsize=(10, 8), constrained_layout=True)
for n in range(0, 10):
    ax[n].imshow(kernel_list[n], cmap = 'gray')

# %% [markdown]
# ### Explanation  of the first layer of a convolutional neural network

# %%
# prepare filter bank kernels
kernel_list = []
for n in range(0, 4):
    theta = n / 4 * np.pi
    kernel = np.real(gabor_kernel(0.15, theta=theta, sigma_x=3, sigma_y=3))
    kernel_list.append(kernel)
fig, ax = plt.subplots(1,4, figsize=(10, 8), constrained_layout=True)
for n in range(0, 4):
    ax[n].imshow(kernel_list[n], cmap = 'gray')
#  
I_layer1=np.zeros((256, 256, 4), dtype='float32')
fig, ax = plt.subplots(1,4, figsize=(10, 8), constrained_layout=True)
for n in range(0, 4):
    I_n = scipy.ndimage.convolve(I_cameraman, kernel_list[n], mode='nearest')
    I_n[I_n<0] = 0
    I_layer1[:,:,n]=I_n
    ax[n].imshow(I_n, cmap = 'gray')   
    #ax[n].axis('off')

# %% [markdown]
# ### An Explanation of the Operations in the second layer of a convolutional neural network
# Apply 2D Convolution to the multi-channel image, I_layer1

# %%
kernel_1 = np.zeros((21, 21, 4), dtype='float32')
for n in range(0, 4):
    theta = n / 4 * np.pi
    kernel_1[:,:,n] = np.real(gabor_kernel(0.3, theta=theta, 
                                         sigma_x=6, sigma_y=6, 
                            half_size=(10,10)))     
fig, ax = plt.subplots(1,4, figsize=(10, 8), constrained_layout=True)
for n in range(0, 4):
    ax[n].imshow(kernel_1[:,:,n], cmap = 'gray')

# %%
kernel_2 = np.zeros((21, 21, 4), dtype='float32')
for n in range(0, 4):
    theta = n / 4 * np.pi
    kernel_2[:,:,n] = np.real(gabor_kernel(0.6, theta=theta, 
                                           sigma_x=3, sigma_y=3, 
                            half_size=(10,10)))     
fig, ax = plt.subplots(1,4, figsize=(10, 8), constrained_layout=True)
for n in range(0, 4):
    ax[n].imshow(kernel_2[:,:,n], cmap = 'gray')

# %%
I_1 = scipy.ndimage.convolve(I_layer1, kernel_1, mode='nearest')
I_1=np.sum(I_1, axis=2)
I_1[I_1<0] = 0
#    
I_2 = scipy.ndimage.convolve(I_layer1, kernel_2, mode='nearest')
I_2=np.sum(I_2, axis=2)
I_2[I_2<0] = 0
#
I_layer2 = np.zeros((256, 256, 2))
I_layer2[:,:,0]=I_1
I_layer2[:,:,1]=I_2
#
fig, ax = plt.subplots(1,2, figsize=(10, 8), constrained_layout=True)    
ax[0].imshow(I_1, cmap = 'gray')    
ax[1].imshow(I_2, cmap = 'gray')   
ax[0].axis('off')
ax[1].axis('off')
# Out:
# (-0.5, 255.5, 255.5, -0.5)
